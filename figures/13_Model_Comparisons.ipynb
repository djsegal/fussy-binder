# %%
using Fussy

using FileIO
using JLD2

using Plots
using Interact

using DataStructures
using StringCases

using LaTeXStrings

pgfplots()
return
# Out:
# <div id="interact-js-shim">
#     <script charset="utf-8">
# (function (IPython, $, _, MathJax) {
#     $.event.special.destroyed = {
# 	remove: function(o) {
# 	    if (o.handler) {
# 		o.handler.apply(this, arguments)
# 	    }
# 	}
#     }
#
#     var OutputArea = IPython.version >= "4.0.0" ? require("notebook/js/outputarea").OutputArea : IPython.OutputArea;
#
#     var redrawValue = function (container, type, val) {
# 	var selector = $("<div/>");
# 	var oa = new OutputArea(_.extend(selector, {
# 	    selector: selector,
# 	    prompt_area: true,
# 	    events: IPython.events,
# 	    keyboard_manager: IPython.keyboard_manager
# 	})); // Hack to work with IPython 2.1.0
#
# 	switch (type) {
# 	case "image/png":
#             var _src = 'data:' + type + ';base64,' + val;
# 	    $(container).find("img").attr('src', _src);
# 	    break;
# 	case "text/latex":
# 		if (MathJax){
# 			var math = MathJax.Hub.getAllJax(container)[0];
# 			MathJax.Hub.Queue(["Text", math, val.replace(/^\${1,2}|\${1,2}$/g, '')]);
# 			break;
# 		}
# 	default:
# 	    var toinsert = OutputArea.append_map[type].apply(
# 		oa, [val, {}, selector]
# 	    );
# 	    $(container).empty().append(toinsert.contents());
# 	    selector.remove();
# 	}
#     }
#
#
#     $(document).ready(function() {
# 	function initComm(evt, data) {
# 	    var comm_manager = data.kernel.comm_manager;
#         //_.extend(comm_manager.targets, require("widgets/js/widget"))
# 	    comm_manager.register_target("Signal", function (comm) {
#             comm.on_msg(function (msg) {
#                 var val = msg.content.data.value;
#                 $(".signal-" + comm.comm_id).each(function() {
#                 var type = $(this).data("type");
#                 if (typeof(val[type]) !== "undefined" && val[type] !== null) {
#                     redrawValue(this, type, val[type], type);
#                 }
#                 });
#                 delete val;
#                 delete msg.content.data.value;
#             });
# 	    });
#
# 	    // coordingate with Comm and redraw Signals
# 	    // XXX: Test using Reactive here to improve performance
# 	    $([IPython.events]).on(
# 		'output_appended.OutputArea', function (event, type, value, md, toinsert) {
# 		    if (md && md.reactive) {
#                 // console.log(md.comm_id);
#                 toinsert.addClass("signal-" + md.comm_id);
#                 toinsert.data("type", type);
#                 // Signal back indicating the mimetype required
#                 var comm_manager = IPython.notebook.kernel.comm_manager;
#                 var comm = comm_manager.comms[md.comm_id];
#                 comm.then(function (c) {
#                     c.send({action: "subscribe_mime",
#                        mime: type});
#                     toinsert.bind("destroyed", function() {
#                         c.send({action: "unsubscribe_mime",
#                                mime: type});
#                     });
#                 })
# 		    }
# 	    });
# 	}
#
# 	try {
# 	    // try to initialize right away. otherwise, wait on the status_started event.
# 	    initComm(undefined, IPython.notebook);
# 	} catch (e) {
# 	    $([IPython.events]).on('kernel_created.Kernel kernel_created.Session', initComm);
# 	}
#     });
# })(IPython, jQuery, _, MathJax);
# </script>
#     <script>
#         window.interactLoadedFlag = true
#        $("#interact-js-shim").bind("destroyed", function () {
#            if (window.interactLoadedFlag) {
#                console.warn("JavaScript required by Interact will be removed if you remove this cell or run using Interact more than once.")
#            }
#        })
#        $([IPython.events]).on("kernel_starting.Kernel kernel_restarting.Kernel", function () { window.interactLoadedFlag = false })
#    </script>
# </div>

# %%
cur_scans = load("../data/comparisons.jld2", "cur_scans")
cur_scans_demo = load("../data/comparisons_demo_tau.jld2", "cur_scans_demo")

cur_scans[:demo_steady_modified] = cur_scans_demo[:demo_steady]
cur_scans[:demo_pulsed_modified] = cur_scans_demo[:demo_pulsed]
# Out:
# Fussy.Scan(AbstractFloat[0.0, 0.333333, 0.666667, 1.0, 1.33333, 1.66667, 2.0, 2.33333, 2.66667, 3.0  …  37.0, 37.3333, 37.6667, 38.0, 38.3333, 38.6667, 39.0, 39.3333, 39.6667, 40.0], :demo_pulsed, Fussy.Reactor[Fussy.Reactor
#   T_bar: Float64 9.66667
#   n_bar: Float64 10904.4
#   I_P: Float64 2.4268
#   R_0: Float64 0.0272552
#   B_0: Float64 1185.43
#   sigma_v: Float64 0.101257
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 0.000289606
#   p_bar: Float64 33282.5
#   P_F: Float64 6804.45
#   beta_N: Float64 0.02591
#   q_95: Float64 16.4798
#   q_DV: Float64 6.21703e5
#   P_E: Float64 3057.92
#   P_W: Float64 3.70893e5
#   norm_beta_N: Float64 1.0
#   norm_q_95: Float64 0.1517
#   norm_q_DV: Float64 62170.3
#   norm_P_E: Float64 2.03861
#   norm_P_W: Float64 46361.6
#   f_BS: Float64 0.945375
#   f_CD: Float64 0.0644019
#   f_IN: Float64 -0.00977727
#   resistance: Float64 2.64022e-6
#   voltage: Float64 -0.0626458
#   inductance: Float64 5.90118e-8
#   volume: Float64 6.66866e-5
#   W_M: Float64 0.0372866
#   cost: Float64 5.47974e-6
#   a: Float64 0.00879252
#   b: Float64 2.17895
#   c: Float64 NaN
#   d: Float64 NaN
#   h_CS: Float64 NaN
#   R_CS: Float64 NaN
#   constraint: Symbol beta
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 1
# , Fussy.Reactor
#   T_bar: Float64 10.0
#   n_bar: Float64 9290.2
#   I_P: Float64 2.52268
#   R_0: Float64 0.0301059
#   B_0: Float64 1110.19
#   sigma_v: Float64 0.107526
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 0.000327075
#   p_bar: Float64 29333.3
#   P_F: Float64 7068.61
#   beta_N: Float64 0.02591
#   q_95: Float64 16.4002
#   q_DV: Float64 5.4359e5
#   P_E: Float64 3176.63
#   P_W: Float64 3.1578e5
#   norm_beta_N: Float64 1.0
#   norm_q_95: Float64 0.152437
#   norm_q_DV: Float64 54359.0
#   norm_P_E: Float64 2.11776
#   norm_P_W: Float64 39472.5
#   f_BS: Float64 0.940806
#   f_CD: Float64 0.0683892
#   f_IN: Float64 -0.00919495
#   resistance: Float64 2.27171e-6
#   voltage: Float64 -0.0526943
#   inductance: Float64 6.5184e-8
#   volume: Float64 8.98765e-5
#   W_M: Float64 0.044076
#   cost: Float64 6.23545e-6
#   a: Float64 0.00971216
#   b: Float64 2.16705
#   c: Float64 NaN
#   d: Float64 NaN
#   h_CS: Float64 NaN
#   R_CS: Float64 NaN
#   constraint: Symbol beta
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 1
# , Fussy.Reactor
#   T_bar: Float64 10.3333
#   n_bar: Float64 7986.36
#   I_P: Float64 2.61972
#   R_0: Float64 0.0330892
#   B_0: Float64 1043.77
#   sigma_v: Float64 0.11378
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 0.000367492
#   p_bar: Float64 26057.1
#   P_F: Float64 7339.0
#   beta_N: Float64 0.02591
#   q_95: Float64 16.3191
#   q_DV: Float64 4.797e5
#   P_E: Float64 3298.14
#   P_W: Float64 2.71405e5
#   norm_beta_N: Float64 1.0
#   norm_q_95: Float64 0.153195
#   norm_q_DV: Float64 47970.0
#   norm_P_E: Float64 2.19876
#   norm_P_W: Float64 33925.6
#   f_BS: Float64 0.936154
#   f_CD: Float64 0.0723666
#   f_IN: Float64 -0.0085209
#   resistance: Float64 1.96769e-6
#   voltage: Float64 -0.0439236
#   inductance: Float64 7.16433e-8
#   volume: Float64 0.00011933
#   W_M: Float64 0.051727
#   cost: Float64 7.04824e-6
#   a: Float64 0.0106746
#   b: Float64 2.15584
#   c: Float64 NaN
#   d: Float64 NaN
#   h_CS: Float64 NaN
#   R_CS: Float64 NaN
#   constraint: Symbol beta
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 1
# , Fussy.Reactor
#   T_bar: Float64 10.6667
#   n_bar: Float64 6920.9
#   I_P: Float64 2.71795
#   R_0: Float64 0.0362053
#   B_0: Float64 984.703
#   sigma_v: Float64 0.120007
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 0.000410997
#   p_bar: Float64 23309.2
#   P_F: Float64 7614.88
#   beta_N: Float64 0.02591
#   q_95: Float64 16.2367
#   q_DV: Float64 4.26766e5
#   P_E: Float64 3422.13
#   P_W: Float64 2.35218e5
#   norm_beta_N: Float64 1.0
#   norm_q_95: Float64 0.153972
#   norm_q_DV: Float64 42676.6
#   norm_P_E: Float64 2.28142
#   norm_P_W: Float64 29402.3
#   f_BS: Float64 0.931426
#   f_CD: Float64 0.0763268
#   f_IN: Float64 -0.00775328
#   resistance: Float64 1.7147e-6
#   voltage: Float64 -0.036134
#   inductance: Float64 7.83903e-8
#   volume: Float64 0.000156318
#   W_M: Float64 0.0603088
#   cost: Float64 7.91986e-6
#   a: Float64 0.0116798
#   b: Float64 2.14525
#   c: Float64 NaN
#   d: Float64 NaN
#   h_CS: Float64 NaN
#   R_CS: Float64 NaN
#   constraint: Symbol beta
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 1
# , Fussy.Reactor
#   T_bar: Float64 11.0
#   n_bar: Float64 6041.04
#   I_P: Float64 2.8174
#   R_0: Float64 0.039455
#   B_0: Float64 931.837
#   sigma_v: Float64 0.126196
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 0.000457734
#   p_bar: Float64 20981.7
#   P_F: Float64 7895.65
#   beta_N: Float64 0.02591
#   q_95: Float64 16.153
#   q_DV: Float64 3.82402e5
#   P_E: Float64 3548.31
#   P_W: Float64 2.0537e5
#   norm_beta_N: Float64 1.0
#   norm_q_95: Float64 0.15477
#   norm_q_DV: Float64 38240.2
#   norm_P_E: Float64 2.36554
#   norm_P_W: Float64 25671.3
#   f_BS: Float64 0.926627
#   f_CD: Float64 0.0802632
#   f_IN: Float64 -0.00689065
#   resistance: Float64 1.5025e-6
#   voltage: Float64 -0.0291691
#   inductance: Float64 8.54262e-8
#   volume: Float64 0.000202301
#   W_M: Float64 0.0698936
#   cost: Float64 8.85217e-6
#   a: Float64 0.0127282
#   b: Float64 2.13521
#   c: Float64 NaN
#   d: Float64 NaN
#   h_CS: Float64 NaN
#   R_CS: Float64 NaN
#   constraint: Symbol beta
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 1
# , Fussy.Reactor
#   T_bar: Float64 11.3333
#   n_bar: Float64 5307.5
#   I_P: Float64 2.9181
#   R_0: Float64 0.0428389
#   B_0: Float64 884.237
#   sigma_v: Float64 0.132338
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 0.00050786
#   p_bar: Float64 18992.6
#   P_F: Float64 8180.76
#   beta_N: Float64 0.02591
#   q_95: Float64 16.0682
#   q_DV: Float64 3.44831e5
#   P_E: Float64 3676.43
#   P_W: Float64 180497.0
#   norm_beta_N: Float64 1.0
#   norm_q_95: Float64 0.155587
#   norm_q_DV: Float64 34483.1
#   norm_P_E: Float64 2.45096
#   norm_P_W: Float64 22562.1
#   f_BS: Float64 0.921762
#   f_CD: Float64 0.0841698
#   f_IN: Float64 -0.00593197
#   resistance: Float64 1.32321e-6
#   voltage: Float64 -0.0229049
#   inductance: Float64 9.2753e-8
#   volume: Float64 0.000258945
#   W_M: Float64 0.0805572
#   cost: Float64 9.84715e-6
#   a: Float64 0.0138198
#   b: Float64 2.12566
#   c: Float64 NaN
#   d: Float64 NaN
#   h_CS: Float64 NaN
#   R_CS: Float64 NaN
#   constraint: Symbol beta
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 1
# , Fussy.Reactor
#   T_bar: Float64 11.6667
#   n_bar: Float64 4690.6
#   I_P: Float64 3.02007
#   R_0: Float64 0.0463583
#   B_0: Float64 841.141
#   sigma_v: Float64 0.138425
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 0.00056154
#   p_bar: Float64 17278.7
#   P_F: Float64 8469.74
#   beta_N: Float64 0.02591
#   q_95: Float64 15.9823
#   q_DV: Float64 3.12714e5
#   P_E: Float64 3806.3
#   P_W: Float64 1.59576e5
#   norm_beta_N: Float64 1.0
#   norm_q_95: Float64 0.156423
#   norm_q_DV: Float64 31271.4
#   norm_P_E: Float64 2.53753
#   norm_P_W: Float64 19947.0
#   f_BS: Float64 0.916835
#   f_CD: Float64 0.0880416
#   f_IN: Float64 -0.00487662
#   resistance: Float64 1.17073e-6
#   voltage: Float64 -0.0172422
#   inductance: Float64 1.00373e-7
#   volume: Float64 0.000328151
#   W_M: Float64 0.0923786
#   cost: Float64 1.09069e-5
#   a: Float64 0.0149552
#   b: Float64 2.11654
#   c: Float64 NaN
#   d: Float64 NaN
#   h_CS: Float64 NaN
#   R_CS: Float64 NaN
#   constraint: Symbol beta
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 1
# , Fussy.Reactor
#   T_bar: Float64 12.0
#   n_bar: Float64 4167.68
#   I_P: Float64 3.12334
#   R_0: Float64 0.0500144
#   B_0: Float64 801.927
#   sigma_v: Float64 0.144451
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 0.000618949
#   p_bar: Float64 15791.1
#   P_F: Float64 8762.17
#   beta_N: Float64 0.02591
#   q_95: Float64 15.8954
#   q_DV: Float64 285024.0
#   P_E: Float64 3937.72
#   P_W: Float64 1.41832e5
#   norm_beta_N: Float64 1.0
#   norm_q_95: Float64 0.157278
#   norm_q_DV: Float64 28502.4
#   norm_P_E: Float64 2.62514
#   norm_P_W: Float64 17729.0
#   f_BS: Float64 0.91185
#   f_CD: Float64 0.0918741
#   f_IN: Float64 -0.00372438
#   resistance: Float64 1.04025e-6
#   voltage: Float64 -0.0121007
#   inductance: Float64 1.08289e-7
#   volume: Float64 0.000412077
#   W_M: Float64 0.105441
#   cost: Float64 1.20336e-5
#   a: Float64 0.0161347
#   b: Float64 2.10782
#   c: Float64 NaN
#   d: Float64 NaN
#   h_CS: Float64 NaN
#   R_CS: Float64 NaN
#   constraint: Symbol beta
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 1
# , Fussy.Reactor
#   T_bar: Float64 12.3333
#   n_bar: Float64 3721.18
#   I_P: Float64 3.22794
#   R_0: Float64 0.053809
#   B_0: Float64 766.081
#   sigma_v: Float64 0.150409
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 0.000680271
#   p_bar: Float64 14491.0
#   P_F: Float64 9057.65
#   beta_N: Float64 0.02591
#   q_95: Float64 15.8076
#   q_DV: Float64 2.60964e5
#   P_E: Float64 4070.51
#   P_W: Float64 1.26666e5
#   norm_beta_N: Float64 1.0
#   norm_q_95: Float64 0.158152
#   norm_q_DV: Float64 26096.4
#   norm_P_E: Float64 2.71367
#   norm_P_W: Float64 15833.2
#   f_BS: Float64 0.906812
#   f_CD: Float64 0.0956634
#   f_IN: Float64 -0.00247553
#   resistance: Float64 9.27958e-7
#   voltage: Float64 -0.00741517
#   inductance: Float64 1.16505e-7
#   volume: Float64 0.000513165
#   W_M: Float64 0.11983
#   cost: Float64 1.32297e-5
#   a: Float64 0.0173588
#   b: Float64 2.09945
#   c: Float64 NaN
#   d: Float64 NaN
#   h_CS: Float64 NaN
#   R_CS: Float64 NaN
#   constraint: Symbol beta
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 1
# , Fussy.Reactor
#   T_bar: Float64 12.6667
#   n_bar: Float64 3337.38
#   I_P: Float64 3.33388
#   R_0: Float64 0.0577438
#   B_0: Float64 733.173
#   sigma_v: Float64 0.156294
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 0.000745702
#   p_bar: Float64 13347.6
#   P_F: Float64 9355.84
#   beta_N: Float64 0.02591
#   q_95: Float64 15.7189
#   q_DV: Float64 2.3991e5
#   P_E: Float64 4204.52
#   P_W: Float64 1.13612e5
#   norm_beta_N: Float64 1.0
#   norm_q_95: Float64 0.159044
#   norm_q_DV: Float64 23991.0
#   norm_P_E: Float64 2.80301
#   norm_P_W: Float64 14201.5
#   f_BS: Float64 0.901725
#   f_CD: Float64 0.0994062
#   f_IN: Float64 -0.00113077
#   resistance: Float64 8.30817e-7
#   voltage: Float64 -0.00313207
#   inductance: Float64 1.25024e-7
#   volume: Float64 0.000634173
#   W_M: Float64 0.135638
#   cost: Float64 1.44976e-5
#   a: Float64 0.0186281
#   b: Float64 2.0914
#   c: Float64 NaN
#   d: Float64 NaN
#   h_CS: Float64 NaN
#   R_CS: Float64 NaN
#   constraint: Symbol beta
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 1
#   …  Fussy.Reactor
#   T_bar: Float64 37.0
#   n_bar: Float64 1.80442
#   I_P: Float64 30.6329
#   R_0: Float64 7.52762
#   B_0: Float64 16.4283
#   sigma_v: Float64 0.377393
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 1.57206
#   p_bar: Float64 21.0803
#   P_F: Float64 14630.5
#   beta_N: Float64 0.02591
#   q_95: Float64 4.99718
#   q_DV: Float64 119.337
#   P_E: Float64 6574.94
#   P_W: Float64 10.4543
#   norm_beta_N: Float64 1.0
#   norm_q_95: Float64 0.500282
#   norm_q_DV: Float64 11.9337
#   norm_P_E: Float64 4.38329
#   norm_P_W: Float64 1.30679
#   f_BS: Float64 0.286666
#   f_CD: Float64 0.24003
#   f_IN: Float64 0.473304
#   resistance: Float64 1.27657e-9
#   voltage: Float64 0.0185085
#   inductance: Float64 1.62985e-5
#   volume: Float64 1404.96
#   W_M: Float64 150.873
#   cost: Float64 0.0103122
#   a: Float64 2.42841
#   b: Float64 1.40368
#   c: Float64 3.19978
#   d: Float64 0.236479
#   h_CS: Float64 16.9293
#   R_CS: Float64 0.259266
#   constraint: Symbol beta
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 4
# , Fussy.Reactor
#   T_bar: Float64 37.3333
#   n_bar: Float64 1.80479
#   I_P: Float64 30.8917
#   R_0: Float64 7.55858
#   B_0: Float64 16.5084
#   sigma_v: Float64 0.378484
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 1.58172
#   p_bar: Float64 21.2746
#   P_F: Float64 14860.6
#   beta_N: Float64 0.02591
#   q_95: Float64 4.99995
#   q_DV: Float64 121.343
#   P_E: Float64 6678.38
#   P_W: Float64 10.532
#   norm_beta_N: Float64 1.0
#   norm_q_95: Float64 0.500005
#   norm_q_DV: Float64 12.1343
#   norm_P_E: Float64 4.45225
#   norm_P_W: Float64 1.3165
#   f_BS: Float64 0.286825
#   f_CD: Float64 0.240724
#   f_IN: Float64 0.472451
#   resistance: Float64 1.25435e-9
#   voltage: Float64 0.018307
#   inductance: Float64 1.63655e-5
#   volume: Float64 1422.37
#   W_M: Float64 154.235
#   cost: Float64 0.0103788
#   a: Float64 2.4384
#   b: Float64 1.40423
#   c: Float64 3.23485
#   d: Float64 0.235127
#   h_CS: Float64 17.0323
#   R_CS: Float64 0.245972
#   constraint: Symbol beta
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 4
# , Fussy.Reactor
#   T_bar: Float64 37.6667
#   n_bar: Float64 1.80506
#   I_P: Float64 31.1515
#   R_0: Float64 7.58974
#   B_0: Float64 16.5875
#   sigma_v: Float64 0.379546
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 1.59154
#   p_bar: Float64 21.4677
#   P_F: Float64 15091.9
#   beta_N: Float64 0.02591
#   q_95: Float64 5.00252
#   q_DV: Float64 123.355
#   P_E: Float64 6782.28
#   P_W: Float64 10.6082
#   norm_beta_N: Float64 1.0
#   norm_q_95: Float64 0.499748
#   norm_q_DV: Float64 12.3355
#   norm_P_E: Float64 4.52152
#   norm_P_W: Float64 1.32603
#   f_BS: Float64 0.286972
#   f_CD: Float64 0.241399
#   f_IN: Float64 0.471628
#   resistance: Float64 1.23266e-9
#   voltage: Float64 0.0181101
#   inductance: Float64 1.6433e-5
#   volume: Float64 1440.03
#   W_M: Float64 157.649
#   cost: Float64 0.010446
#   a: Float64 2.44845
#   b: Float64 1.40476
#   c: Float64 3.26976
#   d: Float64 0.233805
#   h_CS: Float64 17.1351
#   R_CS: Float64 0.232961
#   constraint: Symbol beta
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 4
# , Fussy.Reactor
#   T_bar: Float64 38.0
#   n_bar: Float64 1.80523
#   I_P: Float64 31.4124
#   R_0: Float64 7.62109
#   B_0: Float64 16.6654
#   sigma_v: Float64 0.380579
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 1.60153
#   p_bar: Float64 21.6597
#   P_F: Float64 15324.1
#   beta_N: Float64 0.02591
#   q_95: Float64 5.00488
#   q_DV: Float64 125.371
#   P_E: Float64 6886.66
#   P_W: Float64 10.683
#   norm_beta_N: Float64 1.0
#   norm_q_95: Float64 0.499512
#   norm_q_DV: Float64 12.5371
#   norm_P_E: Float64 4.59111
#   norm_P_W: Float64 1.33538
#   f_BS: Float64 0.287108
#   f_CD: Float64 0.242057
#   f_IN: Float64 0.470836
#   resistance: Float64 1.21147e-9
#   voltage: Float64 0.0179177
#   inductance: Float64 1.65009e-5
#   volume: Float64 1457.95
#   W_M: Float64 161.114
#   cost: Float64 0.0105138
#   a: Float64 2.45856
#   b: Float64 1.40528
#   c: Float64 3.30451
#   d: Float64 0.23251
#   h_CS: Float64 17.2378
#   R_CS: Float64 0.220223
#   constraint: Symbol beta
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 4
# , Fussy.Reactor
#   T_bar: Float64 38.3333
#   n_bar: Float64 1.80531
#   I_P: Float64 31.6742
#   R_0: Float64 7.65262
#   B_0: Float64 16.7423
#   sigma_v: Float64 0.381584
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 1.61169
#   p_bar: Float64 21.8506
#   P_F: Float64 15557.4
#   beta_N: Float64 0.02591
#   q_95: Float64 5.00705
#   q_DV: Float64 127.391
#   P_E: Float64 6991.51
#   P_W: Float64 10.7565
#   norm_beta_N: Float64 1.0
#   norm_q_95: Float64 0.499296
#   norm_q_DV: Float64 12.7391
#   norm_P_E: Float64 4.66101
#   norm_P_W: Float64 1.34456
#   f_BS: Float64 0.287232
#   f_CD: Float64 0.242696
#   f_IN: Float64 0.470072
#   resistance: Float64 1.19077e-9
#   voltage: Float64 0.0177296
#   inductance: Float64 1.65691e-5
#   volume: Float64 1476.12
#   W_M: Float64 164.632
#   cost: Float64 0.0105822
#   a: Float64 2.46873
#   b: Float64 1.40579
#   c: Float64 3.3391
#   d: Float64 0.231243
#   h_CS: Float64 17.3404
#   R_CS: Float64 0.20775
#   constraint: Symbol beta
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 4
# , Fussy.Reactor
#   T_bar: Float64 38.6667
#   n_bar: Float64 1.8053
#   I_P: Float64 31.937
#   R_0: Float64 7.68432
#   B_0: Float64 16.8182
#   sigma_v: Float64 0.382562
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 1.622
#   p_bar: Float64 22.0405
#   P_F: Float64 15791.8
#   beta_N: Float64 0.02591
#   q_95: Float64 5.00903
#   q_DV: Float64 129.416
#   P_E: Float64 7096.82
#   P_W: Float64 10.8286
#   norm_beta_N: Float64 1.0
#   norm_q_95: Float64 0.499099
#   norm_q_DV: Float64 12.9416
#   norm_P_E: Float64 4.73121
#   norm_P_W: Float64 1.35357
#   f_BS: Float64 0.287346
#   f_CD: Float64 0.243318
#   f_IN: Float64 0.469336
#   resistance: Float64 1.17056e-9
#   voltage: Float64 0.0175457
#   inductance: Float64 1.66378e-5
#   volume: Float64 1494.55
#   W_M: Float64 168.201
#   cost: Float64 0.0106512
#   a: Float64 2.47896
#   b: Float64 1.40628
#   c: Float64 3.37355
#   d: Float64 0.230001
#   h_CS: Float64 17.4428
#   R_CS: Float64 0.195533
#   constraint: Symbol beta
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 4
# , Fussy.Reactor
#   T_bar: Float64 39.0
#   n_bar: Float64 1.8052
#   I_P: Float64 32.2008
#   R_0: Float64 7.7162
#   B_0: Float64 16.8931
#   sigma_v: Float64 0.383513
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 1.63247
#   p_bar: Float64 22.2293
#   P_F: Float64 16027.1
#   beta_N: Float64 0.02591
#   q_95: Float64 5.01083
#   q_DV: Float64 131.445
#   P_E: Float64 7202.59
#   P_W: Float64 10.8994
#   norm_beta_N: Float64 1.0
#   norm_q_95: Float64 0.49892
#   norm_q_DV: Float64 13.1445
#   norm_P_E: Float64 4.80173
#   norm_P_W: Float64 1.36242
#   f_BS: Float64 0.287449
#   f_CD: Float64 0.243923
#   f_IN: Float64 0.468628
#   resistance: Float64 1.15081e-9
#   voltage: Float64 0.0173659
#   inductance: Float64 1.67068e-5
#   volume: Float64 1513.22
#   W_M: Float64 171.824
#   cost: Float64 0.0107208
#   a: Float64 2.48925
#   b: Float64 1.40676
#   c: Float64 3.40784
#   d: Float64 0.228784
#   h_CS: Float64 17.545
#   R_CS: Float64 0.183562
#   constraint: Symbol beta
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 4
# , Fussy.Reactor
#   T_bar: Float64 39.3333
#   n_bar: Float64 1.80502
#   I_P: Float64 32.4655
#   R_0: Float64 7.74823
#   B_0: Float64 16.9671
#   sigma_v: Float64 0.384438
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 1.64309
#   p_bar: Float64 22.4171
#   P_F: Float64 16263.5
#   beta_N: Float64 0.02591
#   q_95: Float64 5.01244
#   q_DV: Float64 133.479
#   P_E: Float64 7308.83
#   P_W: Float64 10.9689
#   norm_beta_N: Float64 1.0
#   norm_q_95: Float64 0.498759
#   norm_q_DV: Float64 13.3479
#   norm_P_E: Float64 4.87255
#   norm_P_W: Float64 1.37111
#   f_BS: Float64 0.287542
#   f_CD: Float64 0.244511
#   f_IN: Float64 0.467947
#   resistance: Float64 1.13152e-9
#   voltage: Float64 0.0171901
#   inductance: Float64 1.67761e-5
#   volume: Float64 1532.14
#   W_M: Float64 175.499
#   cost: Float64 0.010791
#   a: Float64 2.49958
#   b: Float64 1.40723
#   c: Float64 3.44199
#   d: Float64 0.227592
#   h_CS: Float64 17.6471
#   R_CS: Float64 0.171831
#   constraint: Symbol beta
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 4
# , Fussy.Reactor
#   T_bar: Float64 39.6667
#   n_bar: Float64 1.80477
#   I_P: Float64 32.7312
#   R_0: Float64 7.78042
#   B_0: Float64 17.0401
#   sigma_v: Float64 0.385338
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 1.65386
#   p_bar: Float64 22.6039
#   P_F: Float64 16500.9
#   beta_N: Float64 0.02591
#   q_95: Float64 5.01389
#   q_DV: Float64 135.517
#   P_E: Float64 7415.51
#   P_W: Float64 11.0371
#   norm_beta_N: Float64 1.0
#   norm_q_95: Float64 0.498615
#   norm_q_DV: Float64 13.5517
#   norm_P_E: Float64 4.94368
#   norm_P_W: Float64 1.37964
#   f_BS: Float64 0.287625
#   f_CD: Float64 0.245083
#   f_IN: Float64 0.467292
#   resistance: Float64 1.11266e-9
#   voltage: Float64 0.0170182
#   inductance: Float64 1.68458e-5
#   volume: Float64 1551.32
#   W_M: Float64 179.228
#   cost: Float64 0.0108617
#   a: Float64 2.50996
#   b: Float64 1.40769
#   c: Float64 3.47601
#   d: Float64 0.226423
#   h_CS: Float64 17.7491
#   R_CS: Float64 0.160329
#   constraint: Symbol beta
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 4
# , Fussy.Reactor
#   T_bar: Float64 40.0
#   n_bar: Float64 1.80444
#   I_P: Float64 32.9978
#   R_0: Float64 7.81274
#   B_0: Float64 17.1122
#   sigma_v: Float64 0.386212
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 1.66478
#   p_bar: Float64 22.7898
#   P_F: Float64 16739.3
#   beta_N: Float64 0.02591
#   q_95: Float64 5.01517
#   q_DV: Float64 137.559
#   P_E: Float64 7522.65
#   P_W: Float64 11.1041
#   norm_beta_N: Float64 1.0
#   norm_q_95: Float64 0.498487
#   norm_q_DV: Float64 13.7559
#   norm_P_E: Float64 5.0151
#   norm_P_W: Float64 1.38801
#   f_BS: Float64 0.287698
#   f_CD: Float64 0.245639
#   f_IN: Float64 0.466663
#   resistance: Float64 1.09423e-9
#   voltage: Float64 0.0168499
#   inductance: Float64 1.69158e-5
#   volume: Float64 1570.73
#   W_M: Float64 183.01
#   cost: Float64 0.0109329
#   a: Float64 2.52039
#   b: Float64 1.40814
#   c: Float64 3.50989
#   d: Float64 0.225276
#   h_CS: Float64 17.8509
#   R_CS: Float64 0.14905
#   constraint: Symbol beta
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 4
# ], Fussy.Reactor[Fussy.Reactor
#   T_bar: Float64 0.333333
#   n_bar: Float64 0.0095142
#   I_P: Float64 0.735244
#   R_0: Float64 16.0606
#   B_0: Float64 0.0924586
#   sigma_v: Float64 5.65297e-8
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool true
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 5.656
#   p_bar: Float64 0.00100135
#   P_F: Float64 5.9173e-7
#   beta_N: Float64 0.0194395
#   q_95: Float64 2.5
#   q_DV: Float64 1.03729e-11
#   P_E: Float64 2.65923e-7
#   P_W: Float64 9.28863e-11
#   norm_beta_N: Float64 0.750271
#   norm_q_95: Float64 1.0
#   norm_q_DV: Float64 1.03729e-12
#   norm_P_E: Float64 1.77282e-10
#   norm_P_W: Float64 1.16108e-11
#   f_BS: Float64 0.107599
#   f_CD: Float64 3.59541e-8
#   f_IN: Float64 0.892401
#   resistance: Float64 6.99719e-7
#   voltage: Float64 0.459108
#   inductance: Float64 3.47738e-5
#   volume: Float64 13645.2
#   W_M: Float64 0.0464124
#   cost: Float64 78435.1
#   a: Float64 5.18116
#   b: Float64 -0.479374
#   c: Float64 0.000540611
#   d: Float64 1.23869
#   h_CS: Float64 15.5184
#   R_CS: Float64 10.1196
#   constraint: Symbol kink
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 1
# , Fussy.Reactor
#   T_bar: Float64 0.666667
#   n_bar: Float64 0.0251758
#   I_P: Float64 1.87466
#   R_0: Float64 15.7653
#   B_0: Float64 0.240159
#   sigma_v: Float64 4.86791e-6
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool true
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 13.2868
#   p_bar: Float64 0.00529943
#   P_F: Float64 0.000337466
#   beta_N: Float64 0.0152484
#   q_95: Float64 2.5
#   q_DV: Float64 1.89465e-8
#   P_E: Float64 0.000151657
#   P_W: Float64 5.49768e-8
#   norm_beta_N: Float64 0.588516
#   norm_q_95: Float64 1.0
#   norm_q_DV: Float64 1.89465e-9
#   norm_P_E: Float64 1.01105e-7
#   norm_P_W: Float64 6.8721e-9
#   f_BS: Float64 0.0844013
#   f_CD: Float64 3.0961e-6
#   f_IN: Float64 0.915596
#   resistance: Float64 2.52022e-7
#   voltage: Float64 0.432578
#   inductance: Float64 3.41343e-5
#   volume: Float64 12906.2
#   W_M: Float64 0.296179
#   cost: Float64 877.655
#   a: Float64 5.08588
#   b: Float64 -0.00701026
#   c: Float64 0.00189007
#   d: Float64 1.17653
#   h_CS: Float64 16.1629
#   R_CS: Float64 9.508
#   constraint: Symbol kink
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 1
# , Fussy.Reactor
#   T_bar: Float64 1.0
#   n_bar: Float64 0.044838
#   I_P: Float64 3.36928
#   R_0: Float64 15.8372
#   B_0: Float64 0.429672
#   sigma_v: Float64 4.26315e-5
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool true
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 24.5768
#   p_bar: Float64 0.0141574
#   P_F: Float64 0.00950328
#   beta_N: Float64 0.0127263
#   q_95: Float64 2.5
#   q_DV: Float64 1.06748e-6
#   P_E: Float64 0.00427077
#   P_W: Float64 1.53415e-6
#   norm_beta_N: Float64 0.491172
#   norm_q_95: Float64 1.0
#   norm_q_DV: Float64 1.06748e-7
#   norm_P_E: Float64 2.84718e-6
#   norm_P_W: Float64 1.91769e-7
#   f_BS: Float64 0.0704409
#   f_CD: Float64 2.71146e-5
#   f_IN: Float64 0.929532
#   resistance: Float64 1.36561e-7
#   voltage: Float64 0.427688
#   inductance: Float64 3.42901e-5
#   volume: Float64 13083.6
#   W_M: Float64 0.961085
#   cost: Float64 101.132
#   a: Float64 5.10908
#   b: Float64 0.239323
#   c: Float64 0.00452399
#   d: Float64 1.15805
#   h_CS: Float64 16.7346
#   R_CS: Float64 9.32622
#   constraint: Symbol kink
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 1
# , Fussy.Reactor
#   T_bar: Float64 1.33333
#   n_bar: Float64 0.0684107
#   I_P: Float64 5.40925
#   R_0: Float64 16.2457
#   B_0: Float64 0.672475
#   sigma_v: Float64 0.000169046
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool true
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 45.0897
#   p_bar: Float64 0.0288005
#   P_F: Float64 0.0946859
#   beta_N: Float64 0.0105691
#   q_95: Float64 2.5
#   q_DV: Float64 1.77484e-5
#   P_E: Float64 0.0425518
#   P_W: Float64 1.45265e-5
#   norm_beta_N: Float64 0.407918
#   norm_q_95: Float64 1.0
#   norm_q_DV: Float64 1.77484e-6
#   norm_P_E: Float64 2.83679e-5
#   norm_P_W: Float64 1.81581e-6
#   f_BS: Float64 0.058501
#   f_CD: Float64 0.000107517
#   f_IN: Float64 0.941391
#   resistance: Float64 8.64682e-8
# ...
#   T_bar: Float64 37.6667
#   n_bar: Float64 1.4939
#   I_P: Float64 31.2524
#   R_0: Float64 8.35629
#   B_0: Float64 18.0039
#   sigma_v: Float64 0.379546
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 1.92304
#   p_bar: Float64 17.7671
#   P_F: Float64 13796.3
#   beta_N: Float64 0.0216817
#   q_95: Float64 5.95879
#   q_DV: Float64 91.6075
#   P_E: Float64 6200.08
#   P_W: Float64 8.0
#   norm_beta_N: Float64 0.836809
#   norm_q_95: Float64 0.419548
#   norm_q_DV: Float64 9.16075
#   norm_P_E: Float64 4.13339
#   norm_P_W: Float64 1.0
#   f_BS: Float64 0.286046
#   f_CD: Float64 0.241399
#   f_IN: Float64 0.472555
#   resistance: Float64 1.11958e-9
#   voltage: Float64 0.0165345
#   inductance: Float64 1.80927e-5
#   volume: Float64 1921.91
#   W_M: Float64 247.871
#   cost: Float64 0.0179664
#   a: Float64 2.69574
#   b: Float64 1.38388
#   c: Float64 3.9179
#   d: Float64 0.223841
#   h_CS: Float64 19.176
#   R_CS: Float64 0.134927
#   constraint: Symbol wall
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 3
# , Fussy.Reactor
#   T_bar: Float64 38.0
#   n_bar: Float64 1.48691
#   I_P: Float64 31.5232
#   R_0: Float64 8.41211
#   B_0: Float64 18.1039
#   sigma_v: Float64 0.380579
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 1.94438
#   p_bar: Float64 17.8405
#   P_F: Float64 13981.3
#   beta_N: Float64 0.0216084
#   q_95: Float64 5.98009
#   q_DV: Float64 92.4377
#   P_E: Float64 6283.19
#   P_W: Float64 8.0
#   norm_beta_N: Float64 0.83398
#   norm_q_95: Float64 0.418054
#   norm_q_DV: Float64 9.24377
#   norm_P_E: Float64 4.1888
#   norm_P_W: Float64 1.0
#   f_BS: Float64 0.286098
#   f_CD: Float64 0.242057
#   f_IN: Float64 0.471845
#   resistance: Float64 1.09755e-9
#   voltage: Float64 0.016325
#   inductance: Float64 1.82136e-5
#   volume: Float64 1960.68
#   W_M: Float64 255.689
#   cost: Float64 0.0182879
#   a: Float64 2.71375
#   b: Float64 1.38388
#   c: Float64 3.97007
#   d: Float64 0.222517
#   h_CS: Float64 19.3376
#   R_CS: Float64 0.121901
#   constraint: Symbol wall
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 3
# , Fussy.Reactor
#   T_bar: Float64 38.3333
#   n_bar: Float64 1.48006
#   I_P: Float64 31.7952
#   R_0: Float64 8.46787
#   B_0: Float64 18.2018
#   sigma_v: Float64 0.381584
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 1.96586
#   p_bar: Float64 17.914
#   P_F: Float64 14167.2
#   beta_N: Float64 0.021538
#   q_95: Float64 6.00051
#   q_DV: Float64 93.2722
#   P_E: Float64 6366.76
#   P_W: Float64 8.0
#   norm_beta_N: Float64 0.831262
#   norm_q_95: Float64 0.416631
#   norm_q_DV: Float64 9.32722
#   norm_P_E: Float64 4.24451
#   norm_P_W: Float64 1.0
#   f_BS: Float64 0.286139
#   f_CD: Float64 0.242696
#   f_IN: Float64 0.471165
#   resistance: Float64 1.07613e-9
#   voltage: Float64 0.0161213
#   inductance: Float64 1.83343e-5
#   volume: Float64 1999.93
#   W_M: Float64 263.634
#   cost: Float64 0.0186087
#   a: Float64 2.73173
#   b: Float64 1.38388
#   c: Float64 4.02182
#   d: Float64 0.221227
#   h_CS: Float64 19.4983
#   R_CS: Float64 0.109206
#   constraint: Symbol wall
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 3
# , Fussy.Reactor
#   T_bar: Float64 38.6667
#   n_bar: Float64 1.47333
#   I_P: Float64 32.0683
#   R_0: Float64 8.52356
#   B_0: Float64 18.2976
#   sigma_v: Float64 0.382562
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 1.98746
#   p_bar: Float64 17.9876
#   P_F: Float64 14354.2
#   beta_N: Float64 0.0214703
#   q_95: Float64 6.02007
#   q_DV: Float64 94.1109
#   P_E: Float64 6450.77
#   P_W: Float64 8.0
#   norm_beta_N: Float64 0.828649
#   norm_q_95: Float64 0.415277
#   norm_q_DV: Float64 9.41109
#   norm_P_E: Float64 4.30052
#   norm_P_W: Float64 1.0
#   f_BS: Float64 0.286169
#   f_CD: Float64 0.243318
#   f_IN: Float64 0.470513
#   resistance: Float64 1.05531e-9
#   voltage: Float64 0.015923
#   inductance: Float64 1.84548e-5
#   volume: Float64 2039.64
#   W_M: Float64 271.709
#   cost: Float64 0.0189289
#   a: Float64 2.7497
#   b: Float64 1.38388
#   c: Float64 4.07319
#   d: Float64 0.219968
#   h_CS: Float64 19.6582
#   R_CS: Float64 0.0968243
#   constraint: Symbol wall
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 3
# , Fussy.Reactor
#   T_bar: Float64 39.0
#   n_bar: Float64 1.46672
#   I_P: Float64 32.3424
#   R_0: Float64 8.57917
#   B_0: Float64 18.3916
#   sigma_v: Float64 0.383513
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 2.00919
#   p_bar: Float64 18.0613
#   P_F: Float64 14542.1
#   beta_N: Float64 0.0214051
#   q_95: Float64 6.03883
#   q_DV: Float64 94.9537
#   P_E: Float64 6535.23
#   P_W: Float64 8.0
#   norm_beta_N: Float64 0.826133
#   norm_q_95: Float64 0.413988
#   norm_q_DV: Float64 9.49537
#   norm_P_E: Float64 4.35682
#   norm_P_W: Float64 1.0
#   f_BS: Float64 0.286189
#   f_CD: Float64 0.243923
#   f_IN: Float64 0.469888
#   resistance: Float64 1.03505e-9
#   voltage: Float64 0.01573
#   inductance: Float64 1.85753e-5
#   volume: Float64 2079.83
#   W_M: Float64 279.914
#   cost: Float64 0.0192485
#   a: Float64 2.76764
#   b: Float64 1.38388
#   c: Float64 4.12418
#   d: Float64 0.218739
#   h_CS: Float64 19.8172
#   R_CS: Float64 0.0847347
#   constraint: Symbol wall
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 3
# , Fussy.Reactor
#   T_bar: Float64 39.3333
#   n_bar: Float64 1.46024
#   I_P: Float64 32.6177
#   R_0: Float64 8.63471
#   B_0: Float64 18.4837
#   sigma_v: Float64 0.384438
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 2.03104
#   p_bar: Float64 18.1352
#   P_F: Float64 14731.0
#   beta_N: Float64 0.0213423
#   q_95: Float64 6.05681
#   q_DV: Float64 95.8006
#   P_E: Float64 6620.11
#   P_W: Float64 8.0
#   norm_beta_N: Float64 0.82371
#   norm_q_95: Float64 0.412759
#   norm_q_DV: Float64 9.58006
#   norm_P_E: Float64 4.41341
#   norm_P_W: Float64 1.0
#   f_BS: Float64 0.2862
#   f_CD: Float64 0.244511
#   f_IN: Float64 0.469289
#   resistance: Float64 1.01535e-9
#   voltage: Float64 0.0155421
#   inductance: Float64 1.86955e-5
#   volume: Float64 2120.48
#   W_M: Float64 288.251
#   cost: Float64 0.0195676
#   a: Float64 2.78556
#   b: Float64 1.38388
#   c: Float64 4.17482
#   d: Float64 0.217538
#   h_CS: Float64 19.9755
#   R_CS: Float64 0.0729173
#   constraint: Symbol wall
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 3
# , Fussy.Reactor
#   T_bar: Float64 39.6667
#   n_bar: Float64 1.45387
#   I_P: Float64 32.894
#   R_0: Float64 8.69017
#   B_0: Float64 18.574
#   sigma_v: Float64 0.385338
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 2.05302
#   p_bar: Float64 18.2091
#   P_F: Float64 14920.8
#   beta_N: Float64 0.0212818
#   q_95: Float64 6.07405
#   q_DV: Float64 96.6514
#   P_E: Float64 6705.43
#   P_W: Float64 8.0
#   norm_beta_N: Float64 0.821375
#   norm_q_95: Float64 0.411587
#   norm_q_DV: Float64 9.66514
#   norm_P_E: Float64 4.47028
#   norm_P_W: Float64 1.0
#   f_BS: Float64 0.286201
#   f_CD: Float64 0.245083
#   f_IN: Float64 0.468716
#   resistance: Float64 9.96179e-10
#   voltage: Float64 0.015359
#   inductance: Float64 1.88156e-5
#   volume: Float64 2161.6
#   W_M: Float64 296.721
#   cost: Float64 0.0198863
#   a: Float64 2.80345
#   b: Float64 1.38388
#   c: Float64 4.22513
#   d: Float64 0.216362
#   h_CS: Float64 20.133
#   R_CS: Float64 0.0613508
#   constraint: Symbol wall
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 3
# , Fussy.Reactor
#   T_bar: Float64 40.0
#   n_bar: Float64 1.44762
#   I_P: Float64 33.1713
#   R_0: Float64 8.74555
#   B_0: Float64 18.6627
#   sigma_v: Float64 0.386212
#   mode_scaling: Dict{Symbol,Float64}
#   deck: Symbol demo_pulsed
#   is_pulsed: Bool true
#   is_symbolic: Bool false
#   is_consistent: Bool false
#   is_solved: Bool true
#   is_valid: Bool false
#   is_good: Bool true
#   H: Float64 1.1
#   Q: Float64 39.86
#   epsilon: Float64 0.3226
#   kappa_95: Float64 1.59
#   delta_95: Float64 0.333
#   nu_n: Float64 0.27
#   nu_T: Float64 1.094
#   Z_eff: Float64 2.584
#   f_D: Float64 0.7753
#   A: Float64 2.735
#   l_i: Float64 1.155
#   rho_m: Float64 0.0
#   gamma: Float64 -2.02534
#   N_G: Float64 1.2
#   eta_T: Float64 0.3531
#   eta_RF: Float64 0.4
#   tau_FT: Float64 7273.0
#   C_ejima: Float64 0.3
#   pi: Float64 3.14159
#   speed_of_light: Float64 3.0e8
#   B_CS: Float64 12.77
#   k: Float64 0.333
#   sigma_CS: Float64 660.0
#   sigma_TF: Float64 660.0
#   J_CS: Float64 50.0
#   J_TF: Float64 230.0
#   max_beta_N: Float64 0.02591
#   max_q_95: Float64 2.5
#   max_q_DV: Float64 10.0
#   max_P_E: Float64 1500.0
#   max_P_W: Float64 8.0
#   eta_CD: Float64 0.2721
#   wave_theta: Float64 135.0
#   eta_LH: Float64 0.6
#   tau_E: Float64 2.07513
#   p_bar: Float64 18.2832
#   P_F: Float64 15111.6
#   beta_N: Float64 0.0212234
#   q_95: Float64 6.0906
#   q_DV: Float64 97.5061
#   P_E: Float64 6791.16
#   P_W: Float64 8.0
#   norm_beta_N: Float64 0.819121
#   norm_q_95: Float64 0.410469
#   norm_q_DV: Float64 9.75061
#   norm_P_E: Float64 4.52744
#   norm_P_W: Float64 1.0
#   f_BS: Float64 0.286193
#   f_CD: Float64 0.245639
#   f_IN: Float64 0.468168
#   resistance: Float64 9.77523e-10
#   voltage: Float64 0.0151807
#   inductance: Float64 1.89355e-5
#   volume: Float64 2203.19
#   W_M: Float64 305.324
#   cost: Float64 0.0202046
#   a: Float64 2.82131
#   b: Float64 1.38388
#   c: Float64 4.27513
#   d: Float64 0.21521
#   h_CS: Float64 20.2898
#   R_CS: Float64 0.0500128
#   constraint: Symbol wall
#   skipped_limits: Array{Symbol}((1,))
#   ignored_limits: Array{Symbol}((1,))
#   branch_id: Int64 3
# ], Fussy.Reactor[])

# %%
function filter_reactors!(reactor_list)
    filter!(Fussy.is_present, reactor_list)
    
    filter!(tmp_reactor -> tmp_reactor.is_valid, reactor_list)
    filter!(tmp_reactor -> tmp_reactor.is_good, reactor_list)
    
    filter!(tmp_reactor -> tmp_reactor.R_0 < 50, reactor_list)
    filter!(tmp_reactor -> tmp_reactor.B_0 < 50, reactor_list)

    filter!(tmp_reactor -> tmp_reactor.cost < 1, reactor_list)
    
    isempty(reactor_list) && return
    ( reactor_list[1].deck == :demo_steady ) && return
    ( reactor_list[1].deck == :act_1 ) && return
    
    filter!(tmp_reactor -> tmp_reactor.norm_P_E < 0.8, reactor_list)
end

return

# %%
function fix_lims!(cur_lims, x, y, xscale, yscale)
    cur_lims[1:2:3] /= 1.2
    cur_lims[2:2:4] *= 1.2
    
    if x == :cost
        cur_lims[1:2] = [0.001, 0.1]
    end
    
    if y == :cost
        cur_lims[3:4] = [0.001, 0.1]
    end
  
    if x == :W_M
        cur_lims[1:2] = [0.01, 100]
    end
    
    if y == :W_M
        cur_lims[3:4] = [0.01, 100]
    end
    
    if x == :B_0 || x == :R_0 || x == :h_CS
        cur_lims[1:2] = [0.05, 20]
    end
    
    if y == :B_0 || y == :R_0 || y == :h_CS
        cur_lims[3:4] = [0.05, 20]
    end
    
    if x == :T_bar || x == :I_P
        cur_lims[1:2] = [0.05, 40]
    end
    
    if y == :T_bar || y == :I_P
        cur_lims[3:4] = [0.05, 40]
    end
  
    if in(x, [:f_IN, :f_BS, :f_CD, :norm_P_W, :norm_beta_N, :norm_q_95])
         cur_lims[2] = 1.25
    end
    
    if in(y, [:f_IN, :f_BS, :f_CD, :norm_P_W, :norm_beta_N, :norm_q_95])
         cur_lims[4] = 1.25
    end
    
    if xscale == "log"
        iszero(cur_lims[1]) || plot!( xscale = :log )
    else
        cur_lims[1] = 0
    end
    
    if yscale == "log"
        iszero(cur_lims[3]) || plot!( yscale = :log )
    else
        cur_lims[3] = 0
    end
end

return

# %%
function make_comparisons(deck, x, y, xscale, yscale)  
    is_pulsed = deck == :proteus || startswith(string(deck), "demo")
    
    if is_pulsed
        other_label = startswith(string(deck), "demo") ? "modified" : "simple"
    else
        other_label = "steady"
    end
    
    other_type = Symbol("$(deck)_$(other_label)")
    
    min_x, max_x = Inf, -Inf
    min_y, max_y = Inf, -Inf
    
    scan_types = [deck, other_type]
    
    is_pulsed || reverse!(scan_types)
    
    for scan_type in scan_types
    
        cur_scan = deepcopy(cur_scans[scan_type])

        cur_dict = OrderedDict()

        cur_dict[:kink] = cur_scan.kink_reactors
        cur_dict[:beta] = cur_scan.beta_reactors
        cur_dict[:wall] = cur_scan.wall_reactors

        for (cur_key, cur_value) in cur_dict
            filter_reactors!(cur_value)

            isempty(cur_value) && continue

            min_branch_id = minimum(map(tmp_reactor -> tmp_reactor.branch_id, cur_value))
            max_branch_id = maximum(map(tmp_reactor -> tmp_reactor.branch_id, cur_value))

            for cur_branch_id in min_branch_id:max_branch_id
                tmp_value = filter(tmp_reactor -> tmp_reactor.branch_id == cur_branch_id, cur_value)
                ( length(tmp_value) > 1 ) || continue

                tmp_tt = map(tmp_reactor -> tmp_reactor.T_bar, tmp_value)

                tmp_xx = map(tmp_reactor -> getfield(tmp_reactor, x), tmp_value)
                tmp_yy = map(tmp_reactor -> getfield(tmp_reactor, y), tmp_value)

                Fussy.sort_lists!(tmp_tt, tmp_xx, tmp_yy)
                
                cur_label = string(cur_key)
                
                if scan_type == other_type 
                    cur_label = "$(other_label) - $(cur_label)"
                    cur_style = is_pulsed ? :dash : :solid
                else
                    cur_label = "pulsed - $(cur_label)"
                    cur_style = is_pulsed ? :solid : :dash
                end
                
                min_x = min(min_x, minimum(tmp_xx))
                min_y = min(min_y, minimum(tmp_yy))
                
                max_x = max(max_x, maximum(tmp_xx))
                max_y = max(max_y, maximum(tmp_yy))
                
                plot!(tmp_xx, tmp_yy, label=cur_label, style=cur_style)
            end
        end
        
    end
    
    cur_lims = [min_x, max_x, min_y, max_y]
    
    fix_lims!(cur_lims, x, y, xscale, yscale)
    
    if isdefined(Fussy, Symbol("$(deck)_solution"))
        cur_solution = getfield(Fussy, Symbol("$(deck)_solution"))()
        tmp_x = getfield(cur_solution, x)
        tmp_y = getfield(cur_solution, y)
        
        ( tmp_x == nothing ) && ( tmp_x = NaN )
        ( tmp_y == nothing ) && ( tmp_y = NaN )
        
        plot!(cur_lims[1:2], [tmp_y, tmp_y], color=:black, opacity=0.5, label="", style=:dot, width=2)
        plot!([tmp_x, tmp_x], cur_lims[3:4], color=:black, opacity=0.5, label="", style=:dot, width=2)
        scatter!([tmp_x], [tmp_y], color=:black, opacity=0.5, label="")
    end
    
    return cur_lims
end

return

# %%
cur_decks = [
    :proteus, # pulsed
    :charybdis, # steady state
    :arc, :act_1, :act_2,
    :demo_pulsed, :demo_steady
]

cur_plots = []

cur_x_list = [:B_0, :T_bar]
cur_y_list = [:R_0, :I_P]

for (cur_x, cur_y) in zip(cur_x_list, cur_y_list)
    for cur_deck in cur_decks
        cur_plot = plot(html_output_format=:svg)

        cur_lims = make_comparisons(cur_deck, cur_x, cur_y, :lin, :lin) 
        
        cur_xlabel = string(cur_x)
        cur_ylabel = string(cur_y)
         
        endswith(cur_xlabel, "_bar") && ( cur_xlabel = "\\overline $( cur_xlabel[1:end-4] )" )
        endswith(cur_ylabel, "_bar") && ( cur_ylabel = "\\overline $( cur_ylabel[1:end-4] )" )
        
        xlabel!(latexstring(cur_xlabel))
        ylabel!(latexstring(cur_ylabel))

        cur_title = string(cur_deck)
        cur_title = join(map(capitalize, split(cur_title, "_")), " ")
        title!(cur_title)

        xlims!(cur_lims[1:2]...)
        ylims!(cur_lims[3:4]...)

        plot!()

        savefig(cur_plot, "../images/comparisons/$(cur_deck)_$(cur_x)_vs_$(cur_y).tex")
    end
end

plot!()
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="427.412pt" height="294.496pt" viewBox="0 0 427.412 294.496" version="1.1">
# <defs>
# <g>
# <symbol overflow="visible" id="glyph-1538348473243945-0-0">
# <path style="stroke:none;" d=""/>
# </symbol>
# <symbol overflow="visible" id="glyph-1538348473243945-0-1">
# <path style="stroke:none;" d="M 4.578125 -3.1875 C 4.578125 -3.984375 4.53125 -4.78125 4.1875 -5.515625 C 3.734375 -6.484375 2.90625 -6.640625 2.5 -6.640625 C 1.890625 -6.640625 1.171875 -6.375 0.75 -5.453125 C 0.4375 -4.765625 0.390625 -3.984375 0.390625 -3.1875 C 0.390625 -2.4375 0.421875 -1.546875 0.84375 -0.78125 C 1.265625 0.015625 2 0.21875 2.484375 0.21875 C 3.015625 0.21875 3.78125 0.015625 4.21875 -0.9375 C 4.53125 -1.625 4.578125 -2.40625 4.578125 -3.1875 Z M 3.765625 -3.3125 C 3.765625 -2.5625 3.765625 -1.890625 3.65625 -1.25 C 3.5 -0.296875 2.9375 0 2.484375 0 C 2.09375 0 1.5 -0.25 1.328125 -1.203125 C 1.21875 -1.796875 1.21875 -2.71875 1.21875 -3.3125 C 1.21875 -3.953125 1.21875 -4.609375 1.296875 -5.140625 C 1.484375 -6.328125 2.234375 -6.421875 2.484375 -6.421875 C 2.8125 -6.421875 3.46875 -6.234375 3.65625 -5.25 C 3.765625 -4.6875 3.765625 -3.9375 3.765625 -3.3125 Z M 3.765625 -3.3125 "/>
# </symbol>
# <symbol overflow="visible" id="glyph-1538348473243945-0-2">
# <path style="stroke:none;" d="M 4.171875 0 L 4.171875 -0.3125 L 3.859375 -0.3125 C 2.953125 -0.3125 2.9375 -0.421875 2.9375 -0.78125 L 2.9375 -6.375 C 2.9375 -6.625 2.9375 -6.640625 2.703125 -6.640625 C 2.078125 -6 1.203125 -6 0.890625 -6 L 0.890625 -5.6875 C 1.09375 -5.6875 1.671875 -5.6875 2.1875 -5.953125 L 2.1875 -0.78125 C 2.1875 -0.421875 2.15625 -0.3125 1.265625 -0.3125 L 0.953125 -0.3125 L 0.953125 0 C 1.296875 -0.03125 2.15625 -0.03125 2.5625 -0.03125 C 2.953125 -0.03125 3.828125 -0.03125 4.171875 0 Z M 4.171875 0 "/>
# </symbol>
# <symbol overflow="visible" id="glyph-1538348473243945-0-3">
# <path style="stroke:none;" d="M 4.46875 -1.734375 L 4.234375 -1.734375 C 4.171875 -1.4375 4.109375 -1 4 -0.84375 C 3.9375 -0.765625 3.28125 -0.765625 3.0625 -0.765625 L 1.265625 -0.765625 L 2.328125 -1.796875 C 3.875 -3.171875 4.46875 -3.703125 4.46875 -4.703125 C 4.46875 -5.84375 3.578125 -6.640625 2.359375 -6.640625 C 1.234375 -6.640625 0.5 -5.71875 0.5 -4.828125 C 0.5 -4.28125 1 -4.28125 1.03125 -4.28125 C 1.203125 -4.28125 1.546875 -4.390625 1.546875 -4.8125 C 1.546875 -5.0625 1.359375 -5.328125 1.015625 -5.328125 C 0.9375 -5.328125 0.921875 -5.328125 0.890625 -5.3125 C 1.109375 -5.96875 1.65625 -6.328125 2.234375 -6.328125 C 3.140625 -6.328125 3.5625 -5.515625 3.5625 -4.703125 C 3.5625 -3.90625 3.078125 -3.125 2.515625 -2.5 L 0.609375 -0.375 C 0.5 -0.265625 0.5 -0.234375 0.5 0 L 4.203125 0 Z M 4.46875 -1.734375 "/>
# </symbol>
# <symbol overflow="visible" id="glyph-1538348473243945-0-4">
# <path style="stroke:none;" d="M 4.5625 -1.703125 C 4.5625 -2.515625 3.921875 -3.296875 2.890625 -3.515625 C 3.703125 -3.78125 4.28125 -4.46875 4.28125 -5.265625 C 4.28125 -6.078125 3.40625 -6.640625 2.453125 -6.640625 C 1.453125 -6.640625 0.6875 -6.046875 0.6875 -5.28125 C 0.6875 -4.953125 0.90625 -4.765625 1.203125 -4.765625 C 1.5 -4.765625 1.703125 -4.984375 1.703125 -5.28125 C 1.703125 -5.765625 1.234375 -5.765625 1.09375 -5.765625 C 1.390625 -6.265625 2.046875 -6.390625 2.40625 -6.390625 C 2.828125 -6.390625 3.375 -6.171875 3.375 -5.28125 C 3.375 -5.15625 3.34375 -4.578125 3.09375 -4.140625 C 2.796875 -3.65625 2.453125 -3.625 2.203125 -3.625 C 2.125 -3.609375 1.890625 -3.59375 1.8125 -3.59375 C 1.734375 -3.578125 1.671875 -3.5625 1.671875 -3.46875 C 1.671875 -3.359375 1.734375 -3.359375 1.90625 -3.359375 L 2.34375 -3.359375 C 3.15625 -3.359375 3.53125 -2.6875 3.53125 -1.703125 C 3.53125 -0.34375 2.84375 -0.0625 2.40625 -0.0625 C 1.96875 -0.0625 1.21875 -0.234375 0.875 -0.8125 C 1.21875 -0.765625 1.53125 -0.984375 1.53125 -1.359375 C 1.53125 -1.71875 1.265625 -1.921875 0.984375 -1.921875 C 0.734375 -1.921875 0.421875 -1.78125 0.421875 -1.34375 C 0.421875 -0.4375 1.34375 0.21875 2.4375 0.21875 C 3.65625 0.21875 4.5625 -0.6875 4.5625 -1.703125 Z M 4.5625 -1.703125 "/>
# </symbol>
# <symbol overflow="visible" id="glyph-1538348473243945-0-5">
# <path style="stroke:none;" d="M 4.6875 -1.640625 L 4.6875 -1.953125 L 3.703125 -1.953125 L 3.703125 -6.484375 C 3.703125 -6.6875 3.703125 -6.75 3.53125 -6.75 C 3.453125 -6.75 3.421875 -6.75 3.34375 -6.625 L 0.28125 -1.953125 L 0.28125 -1.640625 L 2.9375 -1.640625 L 2.9375 -0.78125 C 2.9375 -0.421875 2.90625 -0.3125 2.171875 -0.3125 L 1.96875 -0.3125 L 1.96875 0 C 2.375 -0.03125 2.890625 -0.03125 3.3125 -0.03125 C 3.734375 -0.03125 4.25 -0.03125 4.671875 0 L 4.671875 -0.3125 L 4.453125 -0.3125 C 3.71875 -0.3125 3.703125 -0.421875 3.703125 -0.78125 L 3.703125 -1.640625 Z M 2.984375 -1.953125 L 0.5625 -1.953125 L 2.984375 -5.671875 Z M 2.984375 -1.953125 "/>
# </symbol>
# <symbol overflow="visible" id="glyph-1538348473243945-0-6">
# <path style="stroke:none;" d="M 7.046875 -3.34375 C 7.046875 -5.25 5.703125 -6.8125 4 -6.8125 L 0.34375 -6.8125 L 0.34375 -6.5 L 0.59375 -6.5 C 1.359375 -6.5 1.375 -6.390625 1.375 -6.03125 L 1.375 -0.78125 C 1.375 -0.421875 1.359375 -0.3125 0.59375 -0.3125 L 0.34375 -0.3125 L 0.34375 0 L 4 0 C 5.671875 0 7.046875 -1.46875 7.046875 -3.34375 Z M 6.046875 -3.34375 C 6.046875 -2.25 5.859375 -1.640625 5.5 -1.15625 C 5.296875 -0.890625 4.734375 -0.3125 3.734375 -0.3125 L 2.71875 -0.3125 C 2.25 -0.3125 2.234375 -0.375 2.234375 -0.703125 L 2.234375 -6.09375 C 2.234375 -6.4375 2.25 -6.5 2.71875 -6.5 L 3.71875 -6.5 C 4.34375 -6.5 5.03125 -6.28125 5.53125 -5.578125 C 5.96875 -4.984375 6.046875 -4.125 6.046875 -3.34375 Z M 6.046875 -3.34375 "/>
# </symbol>
# <symbol overflow="visible" id="glyph-1538348473243945-0-7">
# <path style="stroke:none;" d="M 4.140625 -1.1875 C 4.140625 -1.28125 4.0625 -1.3125 4 -1.3125 C 3.921875 -1.3125 3.890625 -1.25 3.875 -1.171875 C 3.53125 -0.140625 2.625 -0.140625 2.53125 -0.140625 C 2.03125 -0.140625 1.640625 -0.4375 1.40625 -0.8125 C 1.109375 -1.28125 1.109375 -1.9375 1.109375 -2.296875 L 3.890625 -2.296875 C 4.109375 -2.296875 4.140625 -2.296875 4.140625 -2.515625 C 4.140625 -3.5 3.59375 -4.46875 2.359375 -4.46875 C 1.203125 -4.46875 0.28125 -3.4375 0.28125 -2.1875 C 0.28125 -0.859375 1.328125 0.109375 2.46875 0.109375 C 3.6875 0.109375 4.140625 -1 4.140625 -1.1875 Z M 3.484375 -2.515625 L 1.109375 -2.515625 C 1.171875 -4 2.015625 -4.25 2.359375 -4.25 C 3.375 -4.25 3.484375 -2.90625 3.484375 -2.515625 Z M 3.484375 -2.515625 "/>
# </symbol>
# <symbol overflow="visible" id="glyph-1538348473243945-0-8">
# <path style="stroke:none;" d="M 8.109375 0 L 8.109375 -0.3125 C 7.59375 -0.3125 7.34375 -0.3125 7.328125 -0.609375 L 7.328125 -2.515625 C 7.328125 -3.375 7.328125 -3.671875 7.015625 -4.03125 C 6.875 -4.203125 6.546875 -4.40625 5.96875 -4.40625 C 5.140625 -4.40625 4.6875 -3.8125 4.53125 -3.421875 C 4.390625 -4.296875 3.65625 -4.40625 3.203125 -4.40625 C 2.46875 -4.40625 2 -3.984375 1.71875 -3.359375 L 1.71875 -4.40625 L 0.3125 -4.296875 L 0.3125 -3.984375 C 1.015625 -3.984375 1.09375 -3.921875 1.09375 -3.421875 L 1.09375 -0.75 C 1.09375 -0.3125 0.984375 -0.3125 0.3125 -0.3125 L 0.3125 0 L 1.453125 -0.03125 L 2.5625 0 L 2.5625 -0.3125 C 1.890625 -0.3125 1.78125 -0.3125 1.78125 -0.75 L 1.78125 -2.59375 C 1.78125 -3.625 2.5 -4.1875 3.125 -4.1875 C 3.765625 -4.1875 3.875 -3.65625 3.875 -3.078125 L 3.875 -0.75 C 3.875 -0.3125 3.765625 -0.3125 3.09375 -0.3125 L 3.09375 0 L 4.21875 -0.03125 L 5.328125 0 L 5.328125 -0.3125 C 4.671875 -0.3125 4.5625 -0.3125 4.5625 -0.75 L 4.5625 -2.59375 C 4.5625 -3.625 5.265625 -4.1875 5.90625 -4.1875 C 6.53125 -4.1875 6.640625 -3.65625 6.640625 -3.078125 L 6.640625 -0.75 C 6.640625 -0.3125 6.53125 -0.3125 5.859375 -0.3125 L 5.859375 0 L 6.984375 -0.03125 Z M 8.109375 0 "/>
# </symbol>
# <symbol overflow="visible" id="glyph-1538348473243945-0-9">
# <path style="stroke:none;" d="M 4.6875 -2.140625 C 4.6875 -3.40625 3.703125 -4.46875 2.5 -4.46875 C 1.25

# %%
cur_best_dict = Dict()
# Out:
# Dict{Any,Any} with 0 entries

# %%
cur_decks = [
    :arc, :act_1, :act_2,
    :demo_steady, :demo_pulsed,
    :proteus, # pulsed
    :charybdis # steady state
]

cur_fields = fieldnames(Fussy.Reactor)
skipped_fields = [
    :rho_m, :gamma, :constraint, :branch_id, :speed_of_light, 
    :pi, :eta_RF, :eta_T, :C_ejima, :k, :wave_theta, :deck,
    :J_TF, :J_CS, :sigma_TF, :sigma_CS, :eta_LH
]

cur_reactors = nothing

solution_keys = []
input_keys = []

for cur_deck in cur_decks    
    cur_reactors = Dict(
        :base => getfield(Fussy, Symbol("$(cur_deck)_deck"))(),
    )
    
    if startswith(string(cur_deck), "demo_") || cur_deck == :proteus
        is_pulsed = true
        is_consistent = false
    else
        is_pulsed = false
        is_consistent = true
    end
    
    is_proto = cur_deck == :proteus || cur_deck == :charybdis
    
    if cur_deck == :proteus
        cur_reactors[:solution] = Fussy.minimize(Fussy.proteus_deck(is_pulsed=is_pulsed, is_consistent=is_consistent), :cost)
    elseif cur_deck == :charybdis
        cur_reactors[:solution] = Fussy.minimize(Fussy.charybdis_deck(is_pulsed=is_pulsed, is_consistent=is_consistent), :cost)
    else
        cur_reactors[:solution] = getfield(Fussy, Symbol("$(cur_deck)_solution"))()
    end
    
    cur_dict = Dict()
    
    for (cur_key, cur_reactor) in cur_reactors
        cur_dict[cur_key] = Dict()
        
        for cur_field in cur_fields
            startswith(string(cur_field), "max_") && continue
            in(cur_field, skipped_fields) && continue
            cur_value = getfield(cur_reactor, cur_field)

            isa(cur_value, Dict) && continue
            isa(cur_value, Vector) && continue
            Fussy.is_nothing(cur_value) && continue

            cur_type = eltype(cur_value)

            ( cur_type == SymEngine.Basic ) && continue 
            ( cur_type == Bool ) && continue 

            cur_dict[cur_key][cur_field] = cur_value
        end
    end
    
    if !is_proto
        tmp_solution_keys = setdiff(map(collect,map(keys,values(cur_dict)))...)
        tmp_input_keys = setdiff(keys(cur_dict[:base]), solution_keys)

        push!(tmp_solution_keys, :eta_CD)
        filter!(cur_key -> cur_key != :eta_CD, tmp_input_keys)

        if isempty(solution_keys) || isempty(input_keys)
            solution_keys = tmp_solution_keys
            input_keys = tmp_input_keys
        else
            @assert solution_keys == tmp_solution_keys
            @assert input_keys == tmp_input_keys
        end
    end
        
    if cur_deck != :proteus && cur_deck != :charybdis
        if haskey(cur_best_dict, cur_deck)
            best_reactor = cur_best_dict[cur_deck]
        else
            cur_suffix = ( startswith(string(cur_deck), "demo_") || cur_deck == :proteus ) ? "" : "_steady"

            cur_vector = vcat(
                cur_scans[Symbol("$(cur_deck)$(cur_suffix)")].kink_reactors,
                cur_scans[Symbol("$(cur_deck)$(cur_suffix)")].beta_reactors,
                cur_scans[Symbol("$(cur_deck)$(cur_suffix)")].wall_reactors
            )

            filter!(tmp_reactor -> tmp_reactor.is_valid, cur_vector)
            filter!(tmp_reactor -> tmp_reactor.is_good, cur_vector)

            cur_error_list = map(
                tmp_reactor -> 
                ( 
                    ( 1 - tmp_reactor.R_0/cur_reactors[:solution].R_0 ) ^ 2 + 
                    ( 1 - tmp_reactor.B_0/cur_reactors[:solution].B_0 ) ^ 2
                ),
                cur_vector
            )

            init_ordering = collect(1:length(cur_vector))

            Fussy.sort_lists!(cur_error_list, cur_vector, init_ordering)

            @assert abs(init_ordering[1]-init_ordering[2]) == 1
            @assert cur_vector[1].constraint == cur_vector[2].constraint

            cur_constraint = cur_vector[1].constraint

            cur_func = function(cur_T_bar)        
                tmp_reactor = Reactor(
                    cur_T_bar, deck=cur_deck, constraint=cur_constraint,
                    is_pulsed=is_pulsed, is_consistent=is_consistent
                )

                @assert tmp_reactor.is_good

                if is_consistent
                    cur_eta_CD = Fussy.converge(tmp_reactor)
                    @assert length(cur_eta_CD) == 1

                    tmp_reactor.eta_CD = cur_eta_CD[1]
                end

                Fussy.solve!(tmp_reactor)

                @assert tmp_reactor.is_valid
                @assert tmp_reactor.is_good

                cur_error = (
                    ( 1 - tmp_reactor.R_0/cur_reactors[:solution].R_0 ) ^ 2 + 
                    ( 1 - tmp_reactor.B_0/cur_reactors[:solution].B_0 ) ^ 2
                )

                cur_error
            end

            best_T_bar = Optim.minimizer(
                Optim.optimize(cur_func, sort([cur_vector[1].T_bar,cur_vector[2].T_bar])...)
            )

            best_reactor = Reactor(
                best_T_bar, deck=cur_deck, constraint=cur_constraint,
                is_pulsed=is_pulsed, is_consistent=is_consistent
            )

            if is_consistent
                cur_eta_CD = Fussy.converge(best_reactor)
                @assert length(cur_eta_CD) == 1

                best_reactor.eta_CD = cur_eta_CD[1]
            end

            Fussy.solve!(best_reactor)

            cur_best_dict[cur_deck] = best_reactor
        end
    end
    
    println()
    println("------")
    println(cur_deck)
    println("------")
    println()
    
    print(rpad("Input", 16))
    print(" | ")
    println(rpad("Value", 16))
    
    println("-"^16, " | ", "-"^16)
    
    for cur_key in input_keys
        tmp_key = string(cur_key)

        if endswith(tmp_key, "_bar")
            tmp_key = "\\overline $( tmp_key[1:end-4] )"
        end
        
        if contains(tmp_key, "_")
            first_part, last_part = split(tmp_key, "_")
            last_part = "\{$(last_part)\}"
            tmp_key = "$(first_part)_$(last_part)"
        end
        
        if any(cur_word -> startswith(tmp_key, "$(cur_word)_") || tmp_key == cur_word, ["eta", "tau", "kappa", "nu", "delta", "epsilon"])
             tmp_key = "\\$(tmp_key)"
        end
        
        print(rpad(latexstring(tmp_key), 16))
        print(" | ")
        println(rpad(getfield(cur_reactors[:base],cur_key), 16))  
    end
    
    println()
    
    print(rpad("Output", 16))
    print(" | ")
    print(rpad(is_proto ? "Value" : "Original", 16))
    
    if is_proto
        println("")
    else
        print(" | ")
        println(rpad("Fussy.jl", 16))
    end
    
    print("-"^16, " | ", "-"^16)
    
    if is_proto
        println("")
    else
        println(" | ", "-"^16)
    end
    
    for cur_key in vcat(solution_keys, [:W_M, :cost, :sigma_v])
        tmp_key = string(cur_key)
        
        if endswith(tmp_key, "_bar")
            tmp_key = "\\overline $( tmp_key[1:end-4] )"
        end
        
        if contains(tmp_key, "_")
            first_part, last_part = split(tmp_key, "_")
            last_part = "\{$(last_part)\}"
            tmp_key = "$(first_part)_$(last_part)"
        end
        
        if any(cur_word -> startswith(tmp_key, "$(cur_word)_") || tmp_key == cur_word, ["eta", "tau", "kappa", "nu", "delta", "epsilon"])
             tmp_key = "\\$(tmp_key)"
        end
        
        print(rpad(latexstring(tmp_key), 16))
        print(" | ")
        try
            print(rpad(signif(round(getfield(cur_reactors[:solution],cur_key),4),4), 16))  
        catch
            print(rpad("-",16))
        end
        
        if is_proto
            println("")
        else
            print(" | ")
            tmp_value = signif(round(getfield(best_reactor,cur_key),4),4)

            isapprox(tmp_value, 0.0, atol=5e-5) && ( tmp_value = 0.0 )
            println(rpad(tmp_value, 16))  
        end
    end
    
end
# Out:
# ------
# arc
# ------
#
# Input            | Value
# ---------------- | ----------------
# $\tau_{FT}$      | 1.6e9
# $f_{D}$          | 0.9
# $\kappa_{95}$    | 1.84
# $\epsilon$       | 0.3333
# $\nu_{n}$        | 0.385
# $A$              | 2.5
# $Q$              | 13.6
# $\delta_{95}$    | 0.333
# $l_{i}$          | 0.67
# $H$              | 1.8
# $\nu_{T}$        | 0.929
# $Z_{eff}$        | 1.2
# $B_{CS}$         | 12.77
# $N_{G}$          | 0.67
#
# Output           | Original         | Fussy.jl
# ---------------- | ---------------- | ----------------
# $f_{CD}$         | 0.37             | 0.4367
# $q_{95}$         | 7.2              | 6.177
# $beta_{N}$       | 0.0259           | 0.0259
# $R_{0}$          | 3.3              | 3.587
# $\overline n$    | 1.3              | 1.131
# $f_{BS}$         | 0.63             | 0.5633
# $volume$         | 141.0            | 187.7
# $\overline T$    | 14.0             | 16.67
# $I_{P}$          | 7.8              | 8.635
# $P_{F}$          | 525.0            | 658.9
# $P_{W}$          | 2.5              | 1.788
# $f_{IN}$         | 0.0              | 0.0
# $B_{0}$          | 9.2              | 8.9
# $\eta_{CD}$      | 0.321            | 0.3157
# $W_{M}$          | -                | 5.916
# $cost$           | -                | 0.009
# $sigma_{v}$      | -                | 0.2403
#
# ------
# act_1
# ------
#
# Input            | Value
# ---------------- | ----------------
# $\tau_{FT}$      | 1.6e9
# $f_{D}$          | 0.75
# $\kappa_{95}$    | 2.1
# $\epsilon$       | 0.25
# $\nu_{n}$        | 0.27
# $A$              | 2.5
# $Q$              | 42.5
# $\delta_{95}$    | 0.4
# $l_{i}$          | 0.35906
# $H$              | 1.65
# $\nu_{T}$        | 1.15
# $Z_{eff}$        | 2.11
# $B_{CS}$         | 12.77
# $N_{G}$          | 1.0
#
# Output           | Original         | Fussy.jl
# ---------------- | ---------------- | ----------------
# $f_{CD}$         | 0.09             | 0.0912
# $q_{95}$         | 4.5              | 4.005
# $beta_{N}$       | 0.0427           | 0.0427
# $R_{0}$          | 6.25             | 8.252
# $\overline n$    | 1.3              | 0.7227
# $f_{BS}$         | 0.91             | 0.9088
# $volume$         | 582.0            | 1446.0
# $\overline T$    | 20.6             | 17.0
# $I_{P}$          | 10.95            | 10.63
# $P_{F}$          | 1813.0           | 1350.0
# $P_{W}$          | 2.45             | 0.8257
# $f_{IN}$         | 0.0              | 0.0
# $B_{0}$          | 6.0              | 4.442
# $\eta_{CD}$      | 0.188            | 0.1819
# $W_{M}$          | -                | 11.36
# $cost$           | -                | 0.0084
# $sigma_{v}$      | -                | 0.2253
#
# ------
# act_2
# ------
#
# Input            | Value
# ---------------- | ----------------
# $\tau_{FT}$      | 1.6e9
# $f_{D}$          | 0.74
# $\kappa_{95}$    | 1.964
# $\epsilon$       | 0.25
# $\nu_{n}$        | 0.41
# $A$              | 2.5
# $Q$              | 25.0
# $\delta_{95}$    | 0.42
# $l_{i}$          | 0.60275
# $H$              | 1.22
# $\nu_{T}$        | 1.15
# $Z_{eff}$        | 2.12
# $B_{CS}$         | 12.77
# $N_{G}$          | 1.3
#
# Output           | Original         | Fussy.jl
# ---------------- | ---------------- | ----------------
# $f_{CD}$         | 0.23             | 0.342
# $q_{95}$         | 8.0              | 6.561
# $beta_{N}$       | 0.026            | 0.0225
# $R_{0}$          | 9.75             | 10.22
# $\overline n$    | 0.86             | 0.819
# $f_{BS}$         | 0.77             | 0.658
# $volume$         | 2209.0           | 2560.0
# $\overline T$    | 17.8             | 17.39
# $I_{P}$          | 13.98            | 14.84
# $P_{F}$          | 2637.0           | 3460.0
# $P_{W}$          | 1.46             | 1.46
# $f_{IN}$         | 0.0              | 0.0
# $B_{0}$          | 8.75             | 9.05
# $\eta_{CD}$      | 0.256            | 0.307
# $W_{M}$          | -                | 83.42
# $cost$           | -                | 0.0241
# $sigma_{v}$      | -                | 0.261
#
# ------
# demo_steady
# ------
#
# Input            | Value
# ---------------- | ----------------
# $\tau_{FT}$      | 1.6e9
# $f_{D}$          | 0.7366
# $\kappa_{95}$    | 1.8
# $\epsilon$       | 0.385
# $\nu_{n}$        | 0.3972
# $A$              | 2.856
# $Q$              | 24.46
# $\delta_{95}$    | 0.333
# $l_{i}$          | 0.9
# $H$              | 1.4
# $\nu_{T}$        | 0.9187
# $Z_{eff}$        | 4.708
# $B_{CS}$         | 12.85
# $N_{G}$          | 1.2
#
# Output           | Original         | Fussy.jl
# ---------------- | ---------------- | ----------------
# $f_{CD}$         | 0.389            | 0.5759
# $q_{95}$         | 4.405            | 3.761
# $beta_{N}$       | 0.038            | 0.038
# $R_{0}$          | 7.5              | 8.154
# $\overline n$    | 0.8746           | 1.048
# $f_{BS}$         | 0.611            | 0.4241
# $volume$         | 2217.0           | 2879.0
# $\overline T$    | 18.07            | 27.83
# $I_{P}$          | 21.63            | 30.93
# $P_{F}$          | 3255.0           | 8971.0
# $P_{W}$          | 1.911            | 4.151
# $f_{IN}$         | 0.0              | 0.0
# $B_{0}$          | 5.627            | 6.307
# $\eta_{CD}$      | 0.4152           | 0.4152
# $W_{M}$          | -                | 45.57
# $cost$           | -                | 0.0051
# $sigma_{v}$      | -                | 0.3706
#
# ------
# demo_pulsed
# ------
#
# Input            | Value
# ---------------- | ----------------
# $\tau_{FT}$      | 7273.0
# $f_{D}$          | 0.7753
# $\kappa_{95}$    | 1.59
# $\epsilon$       | 0.3226
# $\nu_{n}$        | 0.27
# $A$              | 2.735
# $Q$              | 39.86
# $\delta_{95}$    | 0.333
# $l_{i}$          | 1.155
# $H$              | 1.1
# $\nu_{T}$        | 1.094
# $Z_{eff}$        | 2.584
# $B_{CS}$         | 12.77
# $N_{G}$          | 1.2
#
# Output           | Original         | Fussy.jl
# ---------------- | ---------------- | ----------------
# $f_{CD}$         | 0.096            | 0.1062
# $q_{95}$         | 3.247            | 2.853
# $beta_{N}$       | 0.0259           | 0.0259
# $R_{0}$          | 9.072            | 8.1
# $\overline n$    | 0.7983           | 0.9795
# $f_{BS}$         | 0.348            | 0.1637
# $volume$         | 2502.0           | 1751.0
# $\overline T$    | 13.06            | 13.28
# $I_{P}$          | 19.6             | 19.26
# $P_{F}$          | 2037.0           | 2376.0
# $P_{W}$          | 1.05             | 1.466
# $f_{IN}$         | 0.557            | 0.7302
# $B_{0}$          | 5.667            | 5.48
# $\eta_{CD}$      | 0.2721           | 0.2721
# $W_{M}$          | -                | 20.92
# $cost$           | -                | 0.0088
# $sigma_{v}$      | -                | 0.1669
# ------
# proteus
# ------
#
# Input            | Value
# ---------------- | ----------------
# $\tau_{FT}$      | 7200.0
# $f_{D}$          | 0.9
# $\kappa_{95}$    | 1.8
# $\epsilon$       | 0.3
# $\nu_{n}$        | 0.4
# $A$              | 2.5
# $Q$              | 25.0
# $\delta_{95}$    | 0.35
# $l_{i}$          | 0.632845
# $H$              | 1.0
# $\nu_{T}$        | 1.1
# $Z_{eff}$        | 1.75
# $B_{CS}$         | 20.0
# $N_{G}$          | 0.9
#
# Output           | Value
# ---------------- | ----------------
# $f_{CD}$         | 0.0
# $q_{95}$         | 2.5
# $beta_{N}$       | 0.028
# $R_{0}$          | 6.11
# $\overline n$    | 1.158
# $f_{BS}$         | 0.2675
# $volume$         | 732.6
# $\overline T$    | 11.25
# $I_{P}$          | 15.54
# $P_{F}$          | 1667.0
# $P_{W}$          | 1.763
# $f_{IN}$         | 0.7325
# $B_{0}$          | 4.932
# $\eta_{CD}$      | 0.0
# $W_{M}$          | 7.089
# $cost$           | 0.0043
# $sigma_{v}$      | 0.1487
#
# ------
# charybdis
# ------
#
# Input            | Value
# ---------------- | ----------------
# $\tau_{FT}$      | 1.6e9
# $f_{D}$          | 0.9
# $\kappa_{95}$    | 1.8
# $\epsilon$       | 0.3
# $\nu_{n}$        | 0.4
# $A$              | 2.5
# $Q$              | 25.0
# $\delta_{95}$    | 0.35
# $l_{i}$          | 0.557854
# $H$              | 1.7
# $\nu_{T}$        | 1.1
# $Z_{eff}$        | 1.75
# $B_{CS}$         | 12.0
# $N_{G}$          | 0.9
#
# Output           | Value
# ---------------- | ----------------
# $f_{CD}$         | 0.2768
# $q_{95}$         | 6.089
# $beta_{N}$       | 0.028
# $R_{0}$          | 4.125
# $\overline n$    | 1.467
# $f_{BS}$         | 0.7232
# $volume$         | 225.5
# $\overline T$    | 15.81
# $I_{P}$          | 8.978
# $P_{F}$          | 1294.0
# $P_{W}$          | 3.003
# $f_{IN}$         | 0.0
# $B_{0}$          | 10.28
# $\eta_{CD}$      | 0.2905
# $W_{M}$          | 9.479
# $cost$           | 0.0073
# $sigma_{v}$      | 0.2335

# %%
# ss
0.7232 * 8.978
# Out:
# 6.4928896

# %%
# pu
0.2675 * 15.54
# Out:
# 4.15695
